# %%
import pandas as pd
import pickle as pkl

# %%
standings_pkl = pkl.load(open('data/standings_df.pkl', 'rb'))

# %%
standings_pkl.head(4)
# Out:
#   team_id          team_key           name  \
# 0       2  199.l.407818.t.2  b'LaserFloyd'
# 1       6  199.l.407818.t.6  b'touchdownz'
# 2       3  199.l.407818.t.3   b'Old Gregg'
# 3       8  199.l.407818.t.8   b'stoop kid'
#
#                                                  url manager_id  \
# 0  https://football.fantasysports.yahoo.com/2008/...          2
# 1  https://football.fantasysports.yahoo.com/2008/...          6
# 2  https://football.fantasysports.yahoo.com/2008/...          3
# 3  https://football.fantasysports.yahoo.com/2008/...          8
#
#   manager_nickname is_comanager is_commissioner  \
# 0         Zoysia88            0               0
# 1         kevin mc            0               0
# 2            Jacob            0               0
# 3       --hidden--            0               0
#
#                                    manager_image_url felo_score  ...  \
# 0  https://s.yimg.com/ag/images/4570/38823577682_...       None  ...
# ...

# %%
draft_results = pkl.load(open('data/draft_results_df.pkl', 'rb'))

# %%
draft_results.head(5)
# Out:
#   season           team_id round pick  cost    player_key player_name  \
# 0   2008  199.l.407818.t.2     1    4  None    199.p.5228
# 1   2008  199.l.407818.t.2     2   17  None    199.p.7179
# 2   2008  199.l.407818.t.2     3   24  None  199.p.100016
# 3   2008  199.l.407818.t.2     4   37  None    199.p.5854
# 4   2008  199.l.407818.t.2     5   44  None    199.p.6913
#
#   player_position
# 0
# 1
# 2
# 3
# 4

# %%
draft_results['player_key'].value_counts()
# Out:
# player_key
# 199.p.5228      1
# 199.p.7179      1
# 199.p.100016    1
# 199.p.5854      1
# 199.p.6913      1
#                ..
# 406.p.30118     1
# 406.p.24017     1
# 406.p.25876     1
# 406.p.32682     1
# 406.p.100005    1
# Name: count, Length: 2170, dtype: int64

# %%
matchups = pkl.load(open('data/matchups_df.pkl', 'rb'))
matchups.head(3)
# Out:
#   season           team_id week  week_start    week_end     status  \
# 0   2008  199.l.407818.t.2    1  2008-09-02  2008-09-08  postevent
# 1   2008  199.l.407818.t.2    2  2008-09-09  2008-09-15  postevent
# 2   2008  199.l.407818.t.2    3  2008-09-16  2008-09-22  postevent
#
#   is_playoffs is_consolation is_tied  opponent_team_key   opponent_team_name  \
# 0           0              0       0   199.l.407818.t.1  b'Bring Back Barry'
# 1           0              0       0  199.l.407818.t.10    b'Ringer4heisman'
# 2           0              0       0   199.l.407818.t.3         b'Old Gregg'
#
#   our_points opponent_points    winner_team_key
# 0      118.8           117.5   199.l.407818.t.2
# 1       66.2           97.05  199.l.407818.t.10
# 2       96.9          141.85   199.l.407818.t.3

# %%
rosters = pkl.load(open('data/rosters_df.pkl', 'rb'))
rosters.head()
# Out:
#   season           team_id coverage_type week  player_key player_id  \
# 0   2008  199.l.407818.t.2                 16  199.p.7200      7200
# 1   2008  199.l.407818.t.2                 16  199.p.7179      7179
# 2   2008  199.l.407818.t.2                 16  199.p.3514      3514
# 3   2008  199.l.407818.t.2                 16  199.p.7776      7776
# 4   2008  199.l.407818.t.2                 16  199.p.5036      5036
#
#                 name position eligible_positions player_points  \
# 0      Aaron Rodgers                          QB
# 1    Braylon Edwards                          WR
# 2    Marvin Harrison                          WR
# 3  DeAngelo Williams                          RB
# 4       Thomas Jones                          RB
#
#   player_projected_points status status_last_updated bye_weeks injury_note  \
# 0                                                            0
# 1                                                            0
# ...

# %%
rosters[rosters['player_id'] == '7200']['name'][0]
# Out:
# 'Name({\n  "ascii_first": "Aaron",\n  "ascii_last": "Rodgers",\n  "first": "Aaron",\n  "full": "Aaron Rodgers",\n  "last": "Rodgers"\n})'

# %%
rosters = pkl.load(open('data/rosters_df.pkl', 'rb'))

# %%
rosters
# Out:
#      season           team_id coverage_type week    player_key player_id  \
# 0      2008  199.l.407818.t.2                 16    199.p.7200      7200
# 1      2008  199.l.407818.t.2                 16    199.p.7179      7179
# 2      2008  199.l.407818.t.2                 16    199.p.3514      3514
# 3      2008  199.l.407818.t.2                 16    199.p.7776      7776
# 4      2008  199.l.407818.t.2                 16    199.p.5036      5036
# ...     ...               ...           ...  ...           ...       ...
# 2201   2021  406.l.197495.t.4                 17   406.p.33398     33398
# 2202   2021  406.l.197495.t.4                 17   406.p.33408     33408
# 2203   2021  406.l.197495.t.4                 17   406.p.31883     31883
# 2204   2021  406.l.197495.t.4                 17   406.p.31906     31906
# 2205   2021  406.l.197495.t.4                 17  406.p.100026    100026
#
#                                                    name position  \
# ...
